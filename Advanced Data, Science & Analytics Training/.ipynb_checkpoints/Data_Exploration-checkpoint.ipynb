# %% [markdown]
# # Data Exploration

# %%
import pandas as pd

# Load an Excel file
df = pd.read_excel("KRA_Sample_Dataset.xlsx", sheet_name="Sheet1")

# Display first few rows
print(df.head())
# Out:
#   taxpayer_id    taxpayer_name    region         sector taxpayer_type  \
# 0  KE75682867       Nina Quinn   Nairobi         Retail    Individual
# 1  KE66755036     Roger Thomas    Nakuru         Retail    Individual
# 2  KE66882282        Gina Yang  Machakos         Health    Individual
# 3  KE31081788    James Wheeler    Nakuru  Manufacturing     Corporate
# 4  KE23315092  Michael Goodwin     Thika    Agriculture    Individual
#
#    tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid registration_date  \
# 0     81153     52578            54428              108036        2021-04-30
# 1    240128     80025            35870              116525        2020-02-27
# 2     80388     33658           105547               85679        2018-06-20
# 3     36401      7852            51067              125829        2021-03-22
# 4    207903     95986           191657              128216        2018-04-15
#
#   compliance_status
# 0         Compliant
# 1         Compliant
# ...

# %%
#pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 help(read_excel)
#
# NameError: name 'read_excel' is not defined

# %%
# Display the last few rows
print(df.tail())
# Out:
#     taxpayer_id     taxpayer_name    region        sector taxpayer_type  \
# 995  KE60676914     Caitlyn Burns     Nyeri     Transport    Individual
# 996  KE36704425  Stephen Gonzalez  Kakamega        Retail    Individual
# 997  KE71298111   Laurie Valencia     Nyeri   Hospitality    Individual
# 998  KE55014515      Anita Farmer  Kakamega  Construction    Individual
# 999  KE64869006  Jonathan Carlson      Meru  Construction    Individual
#
#      tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid  \
# 995     26253     95108           119269               45436
# 996    462382      3204           199701               11569
# 997    184635     93769            82764              144101
# 998    162462     88265           153956               22490
# 999    355808     32131           158255               45875
#
#     registration_date compliance_status
# 995        2017-02-16     Non-Compliant
# 996        2023-01-05         Compliant
# 997        2018-09-30         Compliant
# ...

# %%
# Geting basic information
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   taxpayer_id         1000 non-null   object
#  1   taxpayer_name       1000 non-null   object
#  2   region              1000 non-null   object
#  3   sector              1000 non-null   object
#  4   taxpayer_type       1000 non-null   object
#  5   tax_paid            1000 non-null   int64
#  6   VAT_paid            1000 non-null   int64
#  7   income_tax_paid     1000 non-null   int64
#  8   corporate_tax_paid  1000 non-null   int64
#  9   registration_date   1000 non-null   datetime64[ns]
#  10  compliance_status   1000 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(6)
# memory usage: 86.1+ KB
# None

# %%
# Statistics summary
print(df.describe())
# Out:
#             tax_paid      VAT_paid  income_tax_paid  corporate_tax_paid  \
# count    1000.000000   1000.000000      1000.000000         1000.000000
# mean   238575.992000  49667.325000    101107.975000        75225.576000
# min      5781.000000   1138.000000      2174.000000          287.000000
# 25%    114655.000000  23775.250000     49744.250000        39152.750000
# 50%    228613.000000  50829.500000    101776.000000        75553.000000
# 75%    360742.250000  75041.000000    151738.250000       111578.250000
# max    498948.000000  99826.000000    199971.000000       149888.000000
# std    143964.174834  28633.449716     57481.637667        43017.255093
#
#                 registration_date
# count                        1000
# mean   2020-04-06 08:51:21.600000
# min           2015-02-12 00:00:00
# 25%           2017-08-15 06:00:00
# 50%           2020-07-16 00:00:00
# 75%           2022-11-01 00:00:00
# max           2025-02-11 00:00:00
# std                           NaN

# %%
# Rows and columns count
print(df.shape)
# Out:
# (1000, 11)

# %%
# List column names
print(df.columns)
# Out:
# Index(['taxpayer_id', 'taxpayer_name', 'region', 'sector', 'taxpayer_type',
#        'tax_paid', 'VAT_paid', 'income_tax_paid', 'corporate_tax_paid',
#        'registration_date', 'compliance_status'],
#       dtype='object')

# %%
# Data types of each column
print (df.dtypes)
# Out:
# taxpayer_id                   object
# taxpayer_name                 object
# region                        object
# sector                        object
# taxpayer_type                 object
# tax_paid                       int64
# VAT_paid                       int64
# income_tax_paid                int64
# corporate_tax_paid             int64
# registration_date     datetime64[ns]
# compliance_status             object
# dtype: object

# %%
# Count of unique values per categorical column
categorical_columns = ["region", "sector", "taxpayer_type", "compliance_status"]
for col in categorical_columns:
    print(f"\nUnique values in {col}:")
    print(df[col].value_counts())
# Out:
# Unique values in region:
# region
# Mombasa     110
# Nairobi     105
# Meru        103
# Kakamega    101
# Thika       100
# Nyeri       100
# Eldoret     100
# Machakos     97
# Nakuru       93
# Kisumu       91
# Name: count, dtype: int64
#
# Unique values in sector:
# sector
# Education        123
# Manufacturing    110
# Hospitality      106
# Retail           102
# Construction     100
# Transport         97
# IT & Tech         95
# Agriculture       90
# Finance           89
# Health            88
# Name: count, dtype: int64
#
# Unique values in taxpayer_type:
# taxpayer_type
# Individual    604
# SME           290
# Corporate     106
# Name: count, dtype: int64
#
# Unique values in compliance_status:
# compliance_status
# Compliant        795
# Non-Compliant    205
# Name: count, dtype: int64

# %% [markdown]
# # Selecting and filtering Data

# %%
# Select columns
print (df['tax_paid'])
df2 = (df['tax_paid'])
# Out:
# 0       81153
# 1      240128
# 2       80388
# 3       36401
# 4      207903
#         ...
# 995     26253
# 996    462382
# 997    184635
# 998    162462
# 999    355808
# Name: tax_paid, Length: 1000, dtype: int64

# %%
# Select multiple columns
df3 = df[['tax_paid','region']]
print(df3)
# Out:
#      tax_paid    region
# 0       81153   Nairobi
# 1      240128    Nakuru
# 2       80388  Machakos
# 3       36401    Nakuru
# 4      207903     Thika
# ..        ...       ...
# 995     26253     Nyeri
# 996    462382  Kakamega
# 997    184635     Nyeri
# 998    162462  Kakamega
# 999    355808      Meru
#
# [1000 rows x 2 columns]

# %%
# Select row by index label 
print(df.loc[200])
# Out:
# taxpayer_id                    KE21506305
# taxpayer_name                David Powell
# region                           Machakos
# sector                          IT & Tech
# taxpayer_type                  Individual
# tax_paid                           233590
# VAT_paid                            29365
# income_tax_paid                    197575
# corporate_tax_paid                  36683
# registration_date     2017-05-04 00:00:00
# compliance_status               Compliant
# Name: 200, dtype: object

# %%
# Select row by integer position
print(df.iloc[200])
# Out:
# taxpayer_id                    KE21506305
# taxpayer_name                David Powell
# region                           Machakos
# sector                          IT & Tech
# taxpayer_type                  Individual
# tax_paid                           233590
# VAT_paid                            29365
# income_tax_paid                    197575
# corporate_tax_paid                  36683
# registration_date     2017-05-04 00:00:00
# compliance_status               Compliant
# Name: 200, dtype: object

# %% [markdown]
# # Filtering and Sorting

# %%
# taxpayers who paid more than KES 200,000
high_tax_payers = df[df["tax_paid"] > 200000] 
high_tax_payers.head()
# Out:
#    taxpayer_id    taxpayer_name   region         sector taxpayer_type  \
# 1   KE66755036     Roger Thomas   Nakuru         Retail    Individual
# 4   KE23315092  Michael Goodwin    Thika    Agriculture    Individual
# 6   KE36735830    Joseph Cortez  Nairobi    Agriculture           SME
# 9   KE98358551    John Crawford  Nairobi    Agriculture     Corporate
# 12  KE23953367     Jason Tanner  Mombasa  Manufacturing    Individual
#
#     tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid registration_date  \
# 1     240128     80025            35870              116525        2020-02-27
# 4     207903     95986           191657              128216        2018-04-15
# 6     237601     72947           154679               65901        2023-09-23
# 9     256459     52707           144980               90012        2021-11-03
# 12    454042     76939            63215              102476        2023-03-06
#
#    compliance_status
# 1          Compliant
# 4          Compliant
# ...

# %%
high_tax_payers.tail()
# Out:
#     taxpayer_id      taxpayer_name    region        sector taxpayer_type  \
# 987  KE62840397    Jacob Hernandez   Nairobi  Construction    Individual
# 990  KE54132455    Matthew Sellers  Machakos     Education    Individual
# 992  KE20016389  Rebecca Rodriguez     Thika       Finance    Individual
# 996  KE36704425   Stephen Gonzalez  Kakamega        Retail    Individual
# 999  KE64869006   Jonathan Carlson      Meru  Construction    Individual
#
#      tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid  \
# 987    280709     28606           153396               11350
# 990    358323     80303           149616               97557
# 992    448945     63522            31063               17576
# 996    462382      3204           199701               11569
# 999    355808     32131           158255               45875
#
#     registration_date compliance_status
# 987        2024-06-23     Non-Compliant
# 990        2023-08-22         Compliant
# ...

# %%
high_tax_payers.shape
# Out:
# (555, 11)

# %%
# Sorting by tax paid
sorted_tax_payers = df.sort_values(by="tax_paid", ascending=False)  
sorted_tax_payers.head()
# Out:
#     taxpayer_id    taxpayer_name    region         sector taxpayer_type  \
# 104  KE73203558  David Hernandez      Meru         Health           SME
# 762  KE20320855    Michael Moore    Kisumu  Manufacturing    Individual
# 318  KE89688895  Annette Jackson    Kisumu   Construction    Individual
# 49   KE83506850   Dustin Bradley   Eldoret      IT & Tech    Individual
# 916  KE90480036   Theresa Hughes  Machakos      Education    Individual
#
#      tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid  \
# 104    498948     26556           130389              116545
# 762    498253     24782            46942               84149
# 318    498158     30033            54874               13233
# 49     497289      6906           115000               70014
# 916    497092     81098            37931                2035
#
#     registration_date compliance_status
# 104        2022-06-29         Compliant
# 762        2025-01-25         Compliant
# 318        2024-06-24         Compliant
# ...

# %%
sorted_tax_payers.tail()
# Out:
#     taxpayer_id    taxpayer_name    region        sector taxpayer_type  \
# 596  KE11286643       Robin Reed  Kakamega     Education    Individual
# 411  KE41530803      Jesus Logan   Eldoret  Construction    Individual
# 768  KE75377052  Monica Randolph   Mombasa  Construction    Individual
# 405  KE10449395    Charles Stone   Nairobi     Transport           SME
# 976  KE18351245       Alex Perez      Meru        Health    Individual
#
#      tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid  \
# 596      8754     47840           183561               78537
# 411      8631     20086           127355              105583
# 768      8471     36596            10328              114456
# 405      8191     11651             6986               25901
# 976      5781     34487           119603               35932
#
#     registration_date compliance_status
# 596        2016-09-24         Compliant
# 411        2019-07-22         Compliant
# 768        2021-03-14     Non-Compliant
# ...

# %% [markdown]
# # String Operations on Data

# %%
# Convert names to uppercase
df["taxpayer_name"] = df["taxpayer_name"].str.upper()

# %%
# Extract numeric part of ID
df_kra["taxpayer_pin"] = df_kra["taxpayer_id"].str.extract(r'KE(\d+)')

# %% [markdown]
# # Changing Data Types

# %%
 # Convert to datetime

df["registration_date"] = pd.to_datetime(df["registration_date"])

# %% [markdown]
# # Handling Missing Values

# %%
# Check missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# taxpayer_id           0
# taxpayer_name         0
# region                0
# sector                0
# taxpayer_type         0
# tax_paid              0
# VAT_paid              0
# income_tax_paid       0
# corporate_tax_paid    0
# registration_date     0
# compliance_status     0
# dtype: int64

# %%
# Fill missing tax values with median
df["tax_paid"].fillna(df["tax_paid"].median(), inplace=True)
# Out:
# C:\Users\Fanuel\AppData\Local\Temp\ipykernel_14052\3515314445.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["tax_paid"].fillna(df["tax_paid"].median(), inplace=True)

# %% [markdown]
# # Handling Duplicates

# %%
# Count duplicates
duplicate_count = df.duplicated().sum()  
duplicate_count
# Out:
# 0

# %%
# Remove duplicates by taxpayer_id
df.drop_duplicates(subset=["taxpayer_id"], keep="first", inplace=True)

# %% [markdown]
# # Aggregating Data

# %%
# Total tax per region
tax_per_region = df.groupby("region")["tax_paid"].sum()  
tax_per_region
# Out:
# region
# Eldoret     21503741
# Kakamega    27815106
# Kisumu      23358871
# Machakos    23340658
# Meru        24895384
# Mombasa     26315121
# Nairobi     24329114
# Nakuru      19975796
# Nyeri       23556210
# Thika       23485991
# Name: tax_paid, dtype: int64

# %%
pd.DataFrame.groupby?
# Out:
# Signature:
# pd.DataFrame.groupby(
#     self,
#     by=None,
#     axis: 'Axis | lib.NoDefault' = <no_default>,
#     level: 'IndexLabel | None' = None,
#     as_index: 'bool' = True,
#     sort: 'bool' = True,
#     group_keys: 'bool' = True,
#     observed: 'bool | lib.NoDefault' = <no_default>,
#     dropna: 'bool' = True,
# ) -> 'DataFrameGroupBy'
# Docstring:
# Group DataFrame using a mapper or by a Series of columns.
#
# A groupby operation involves some combination of splitting the
# object, applying a function, and combining the results. This can be
# used to group large amounts of data and compute operations on these
# groups.
#
# Parameters
# ----------
# by : mapping, function, label, pd.Grouper or list of such
#     Used to determine the groups for the groupby.
#     If ``by`` is a function, it's called on each value of the object's
#     index. If a dict or Series is passed, the Series or dict VALUES
# ...

# %%
# Average VAT per sector
avg_vat_per_sector = df.groupby("sector")["VAT_paid"].mean() 
avg_vat_per_sector
# Out:
# sector
# Agriculture      56299.588889
# Construction     53058.530000
# Education        50696.715447
# Finance          45212.235955
# Health           47485.625000
# Hospitality      50703.632075
# IT & Tech        52549.778947
# Manufacturing    43295.981818
# Retail           46996.833333
# Transport        50857.113402
# Name: VAT_paid, dtype: float64

# %%
# Count taxpayers per region
taxpayer_count = df.groupby("region")["taxpayer_id"].count() 
taxpayer_count
# Out:
# region
# Eldoret     100
# Kakamega    101
# Kisumu       91
# Machakos     97
# Meru        103
# Mombasa     110
# Nairobi     105
# Nakuru       93
# Nyeri       100
# Thika       100
# Name: taxpayer_id, dtype: int64

# %% [markdown]
# # Merging Datasets

# %%
 # Sample dataset
df_tax_compliance = df[["taxpayer_id", "compliance_status"]].sample(frac=1).reset_index(drop=True) 
df_tax_compliance
# Out:
#     taxpayer_id compliance_status
# 0    KE53351876         Compliant
# 1    KE56216125     Non-Compliant
# 2    KE64474455         Compliant
# 3    KE69994988         Compliant
# 4    KE88725274     Non-Compliant
# ..          ...               ...
# 995  KE67631343         Compliant
# 996  KE12976242         Compliant
# 997  KE94302960         Compliant
# 998  KE45912253     Non-Compliant
# 999  KE64717184         Compliant
#
# [1000 rows x 2 columns]

# %%
# Merge datasets
df_merged = pd.merge(df, df_tax_compliance, on="taxpayer_id", how="inner", suffixes=("_orig", "_compliance"))  
df_merged
# Out:
#     taxpayer_id     taxpayer_name    region         sector taxpayer_type  \
# 0    KE75682867        NINA QUINN   Nairobi         Retail    Individual
# 1    KE66755036      ROGER THOMAS    Nakuru         Retail    Individual
# 2    KE66882282         GINA YANG  Machakos         Health    Individual
# 3    KE31081788     JAMES WHEELER    Nakuru  Manufacturing     Corporate
# 4    KE23315092   MICHAEL GOODWIN     Thika    Agriculture    Individual
# ..          ...               ...       ...            ...           ...
# 995  KE60676914     CAITLYN BURNS     Nyeri      Transport    Individual
# 996  KE36704425  STEPHEN GONZALEZ  Kakamega         Retail    Individual
# 997  KE71298111   LAURIE VALENCIA     Nyeri    Hospitality    Individual
# 998  KE55014515      ANITA FARMER  Kakamega   Construction    Individual
# 999  KE64869006  JONATHAN CARLSON      Meru   Construction    Individual
#
#      tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid  \
# ...

# %% [markdown]
# # Descriptive Statistics

# %%
summary_statistics = df.describe()
summary_statistics
# Out:
#             tax_paid      VAT_paid  income_tax_paid  corporate_tax_paid  \
# count    1000.000000   1000.000000      1000.000000         1000.000000
# mean   238575.992000  49667.325000    101107.975000        75225.576000
# min      5781.000000   1138.000000      2174.000000          287.000000
# 25%    114655.000000  23775.250000     49744.250000        39152.750000
# 50%    228613.000000  50829.500000    101776.000000        75553.000000
# 75%    360742.250000  75041.000000    151738.250000       111578.250000
# max    498948.000000  99826.000000    199971.000000       149888.000000
# std    143964.174834  28633.449716     57481.637667        43017.255093
#
#                 registration_date
# count                        1000
# mean   2020-04-06 08:51:21.600000
# min           2015-02-12 00:00:00
# 25%           2017-08-15 06:00:00
# 50%           2020-07-16 00:00:00
# 75%           2022-11-01 00:00:00
# max           2025-02-11 00:00:00
# std                           NaN

# %%
# Correlation matrix of numerical features
continuous_columns = df.select_dtypes(include=['number']).columns.tolist()
print("\nCorrelation matrix of continuous variables:")
print(df[continuous_columns].corr())
# Out:
# Correlation matrix of continuous variables:
#                     tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid
# tax_paid            1.000000  0.017675        -0.023196            0.024190
# VAT_paid            0.017675  1.000000        -0.007595            0.002230
# income_tax_paid    -0.023196 -0.007595         1.000000           -0.023621
# corporate_tax_paid  0.024190  0.002230        -0.023621            1.000000

# %% [markdown]
# # Exercise

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Load the dataset into a Pandas DataFrame and display the first 5 rows.

# %%
import pandas as pd

df = pd.read_excel("KRA_Class_Dataset.xlsx", sheet_name="Sheet1")

print(df.head())
# Out:
#   taxpayer_id  taxpayer_name    region         sector taxpayer_type  tax_paid  \
# 0  KE75682867  Brandon Smith   Nairobi         Retail    Individual     81153
# 1  KE66755036   Megan Patton    Nakuru         Retail    Individual    240128
# 2  KE66882282  James Douglas  Machakos         Health    Individual     80388
# 3  KE31081788    Haley Moore    Nakuru  Manufacturing     Corporate     36401
# 4  KE23315092      Dean Kemp     Thika    Agriculture    Individual    207903
#
#    VAT_paid  income_tax_paid  corporate_tax_paid registration_date  \
# 0     52578            54428              108036        2022-06-16
# 1     80025            35870              116525        2024-02-02
# 2     33658           105547               85679        2017-07-12
# 3      7852            51067              125829        2023-07-06
# 4     95986           191657              128216        2015-04-14
#
#   compliance_status
# 0         Compliant
# 1         Compliant
# 2         Compliant
# ...

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# Filter taxpayers who have paid more than 300,000 KES in tax.

# %%
high_tax_payers = df[df['tax_paid'] > 300000]
print(high_tax_payers)
high_tax_payers.head()
# Out:
#     taxpayer_id     taxpayer_name    region         sector taxpayer_type  \
# 12   KE23953367    Andrea Johnson   Mombasa  Manufacturing    Individual
# 13   KE95652971   Matthew Elliott  Kakamega      Transport    Individual
# 16   KE86893497  Curtis Hernandez   Nairobi        Finance    Individual
# 17   KE40349564       Jodi Torres     Thika      IT & Tech           SME
# 18   KE52860080     Kevin Jenkins     Thika    Agriculture    Individual
# ..          ...               ...       ...            ...           ...
# 978  KE46640608     Kayla Jenkins  Kakamega    Hospitality    Individual
# 990  KE54132455      Edward Scott  Machakos      Education    Individual
# 992  KE20016389    Jennifer Hicks     Thika        Finance    Individual
# 996  KE36704425  Zachary Robinson  Kakamega         Retail    Individual
# 999  KE64869006     Michael Lopez      Meru   Construction    Individual
#
#      tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid  \
# ...

# %%
high_tax_payers = df[df['tax_paid'] > 300000]
high_tax_payers = high_tax_payers.sort_values(by='tax_paid' , ascending = False)
#print(high_tax_payers.head())
high_tax_payers.head()
# Out:
#     taxpayer_id  taxpayer_name    region         sector taxpayer_type  \
# 104  KE73203558   Rachel Brown      Meru         Health           SME
# 762  KE20320855   Tricia Smith    Kisumu  Manufacturing    Individual
# 318  KE89688895  Nicole Martin    Kisumu   Construction    Individual
# 49   KE83506850       Amy Haas   Eldoret      IT & Tech    Individual
# 916  KE90480036  Nicole Hughes  Machakos      Education    Individual
#
#      tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid  \
# 104    498948     26556           130389              116545
# 762    498253     24782            46942               84149
# 318    498158     30033            54874               13233
# 49     497289      6906           115000               70014
# 916    497092     81098            37931                2035
#
#     registration_date compliance_status
# 104        2023-11-08         Compliant
# 762        2015-10-08         Compliant
# 318        2021-04-24         Compliant
# ...

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# Sort the dataset by the amount of tax paid in descending order.

# %%
#print(df.sort_values(by = 'tax_paid', ascending = False).head())
descending_amount = df.sort_values(by = 'tax_paid', ascending = False)
descending_amount.head()
# Out:
#     taxpayer_id  taxpayer_name    region         sector taxpayer_type  \
# 104  KE73203558   Rachel Brown      Meru         Health           SME
# 762  KE20320855   Tricia Smith    Kisumu  Manufacturing    Individual
# 318  KE89688895  Nicole Martin    Kisumu   Construction    Individual
# 49   KE83506850       Amy Haas   Eldoret      IT & Tech    Individual
# 916  KE90480036  Nicole Hughes  Machakos      Education    Individual
#
#      tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid  \
# 104    498948     26556           130389              116545
# 762    498253     24782            46942               84149
# 318    498158     30033            54874               13233
# 49     497289      6906           115000               70014
# 916    497092     81098            37931                2035
#
#     registration_date compliance_status
# 104        2023-11-08         Compliant
# 762        2015-10-08         Compliant
# 318        2021-04-24         Compliant
# ...

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# Convert all taxpayer names to uppercase

# %%
df['taxpayer_name'] = df['taxpayer_name'].str.upper()
df.head()
# Out:
#   taxpayer_id  taxpayer_name    region         sector taxpayer_type  tax_paid  \
# 0  KE75682867  BRANDON SMITH   Nairobi         Retail    Individual     81153
# 1  KE66755036   MEGAN PATTON    Nakuru         Retail    Individual    240128
# 2  KE66882282  JAMES DOUGLAS  Machakos         Health    Individual     80388
# 3  KE31081788    HALEY MOORE    Nakuru  Manufacturing     Corporate     36401
# 4  KE23315092      DEAN KEMP     Thika    Agriculture    Individual    207903
#
#    VAT_paid  income_tax_paid  corporate_tax_paid registration_date  \
# 0     52578            54428              108036        2022-06-16
# 1     80025            35870              116525        2024-02-02
# 2     33658           105547               85679        2017-07-12
# 3      7852            51067              125829        2023-07-06
# 4     95986           191657              128216        2015-04-14
#
#   compliance_status
# 0         Compliant
# 1         Compliant
# 2         Compliant
# ...

# %% [markdown]
# ## Exercise 5

# %% [markdown]
# Extract the numeric portion from the taxpayer ID (e.g., 'KE12345678' -> '12345678').

# %%
df["taxpayer_pin"] = df["taxpayer_id"].str.extract(r'KE(\d+)')  
df.head
# Out:
# <bound method NDFrame.head of     taxpayer_id     taxpayer_name    region         sector taxpayer_type  \
# 0    KE75682867     BRANDON SMITH   Nairobi         Retail    Individual
# 1    KE66755036      MEGAN PATTON    Nakuru         Retail    Individual
# 2    KE66882282     JAMES DOUGLAS  Machakos         Health    Individual
# 3    KE31081788       HALEY MOORE    Nakuru  Manufacturing     Corporate
# 4    KE23315092         DEAN KEMP     Thika    Agriculture    Individual
# ..          ...               ...       ...            ...           ...
# 995  KE60676914  WALTER GUTIERREZ     Nyeri      Transport    Individual
# 996  KE36704425  ZACHARY ROBINSON  Kakamega         Retail    Individual
# 997  KE71298111  HANNAH UNDERWOOD     Nyeri    Hospitality    Individual
# 998  KE55014515        LUKE DRAKE  Kakamega   Construction    Individual
# 999  KE64869006     MICHAEL LOPEZ      Meru   Construction    Individual
#
# ...

# %%
df['taxpayer_id'] = df['taxpayer_id'].str.extract('(\d+)')
#print(df[['taxpayer_id', 'taxpayer_id']].head())  # Display the first few rows
df.head()
# Out:
#   taxpayer_id  taxpayer_name    region         sector taxpayer_type  tax_paid  \
# 0    75682867  BRANDON SMITH   Nairobi         Retail    Individual     81153
# 1    66755036   MEGAN PATTON    Nakuru         Retail    Individual    240128
# 2    66882282  JAMES DOUGLAS  Machakos         Health    Individual     80388
# 3    31081788    HALEY MOORE    Nakuru  Manufacturing     Corporate     36401
# 4    23315092      DEAN KEMP     Thika    Agriculture    Individual    207903
#
#    VAT_paid  income_tax_paid  corporate_tax_paid registration_date  \
# 0     52578            54428              108036        2022-06-16
# 1     80025            35870              116525        2024-02-02
# 2     33658           105547               85679        2017-07-12
# 3      7852            51067              125829        2023-07-06
# 4     95986           191657              128216        2015-04-14
#
#   compliance_status taxpayer_pin taxpayer_id_numeric
# ...

# %% [markdown]
# ## Exercise 6

# %% [markdown]
# Count the number of taxpayers per region

# %%
categorical_columns = ["region"]
for col in categorical_columns:
    print(f"\nUnique values in {col}:")
    print(df[col].value_counts())
# Out:
# Unique values in region:
# Mombasa     110
# Nairobi     105
# Meru        103
# Kakamega    101
# Nyeri       100
# Eldoret     100
# Thika       100
# Machakos     97
# Nakuru       93
# Kisumu       91
# Name: region, dtype: int64

# %%
taxpayer_count_per_region = df.groupby('region')['taxpayer_id'].count()
print(taxpayer_count_per_region)
# Out:
# region
# Eldoret     100
# Kakamega    101
# Kisumu       91
# Machakos     97
# Meru        103
# Mombasa     110
# Nairobi     105
# Nakuru       93
# Nyeri       100
# Thika       100
# Name: taxpayer_id, dtype: int64

# %%
print(df['region'].value_counts())
# Out:
# Mombasa     110
# Nairobi     105
# Meru        103
# Kakamega    101
# Nyeri       100
# Eldoret     100
# Thika       100
# Machakos     97
# Nakuru       93
# Kisumu       91
# Name: region, dtype: int64

# %% [markdown]
# ## Exercise 7

# %% [markdown]
# Find the total tax collected per sector.

# %%
categorical_columns = ['tax_paid', 'income_tax_paid', 'corporate_tax_paid']

total_tax_per_sector = df.groupby('sector')[categorical_columns].sum()
print(total_tax_per_sector)
# Out:
#                tax_paid  income_tax_paid  corporate_tax_paid
# sector
# Agriculture    24157013          9181716             6327239
# Construction   24143047         10045093             7751231
# Education      31307726         11893104             8802652
# Finance        19756769          9356839             6825072
# Health         21340778          9413847             6979584
# Hospitality    23485686          9967164             8580437
# IT & Tech      21554273          9711880             6817124
# Manufacturing  27938699         10988733             8537699
# Retail         22845099          9968616             7969671
# Transport      22046902         10580983             6634867

# %% [markdown]
# ## Exercise 8

# %% [markdown]
# Remove any duplicate taxpayer records based on the taxpayer ID

# %%
#duplicate_count = df.duplicated().sum()  
#duplicate_count
df.drop_duplicates(subset=["taxpayer_id"], keep="first", inplace=True)

# %%
#df = df.drop_duplicates(subset=['taxpayer_id'], keep='first')  # Keeps the first occurrence
#print(df)
# Out:
#     taxpayer_id     taxpayer_name    region         sector taxpayer_type  \
# 0      75682867     BRANDON SMITH   Nairobi         Retail    Individual
# 1      66755036      MEGAN PATTON    Nakuru         Retail    Individual
# 2      66882282     JAMES DOUGLAS  Machakos         Health    Individual
# 3      31081788       HALEY MOORE    Nakuru  Manufacturing     Corporate
# 4      23315092         DEAN KEMP     Thika    Agriculture    Individual
# ..          ...               ...       ...            ...           ...
# 995    60676914  WALTER GUTIERREZ     Nyeri      Transport    Individual
# 996    36704425  ZACHARY ROBINSON  Kakamega         Retail    Individual
# 997    71298111  HANNAH UNDERWOOD     Nyeri    Hospitality    Individual
# 998    55014515        LUKE DRAKE  Kakamega   Construction    Individual
# 999    64869006     MICHAEL LOPEZ      Meru   Construction    Individual
#
#      tax_paid  VAT_paid  income_tax_paid  corporate_tax_paid  \
# ...

# %% [markdown]
# ## Exercise 9

# %% [markdown]
# Convert the registration date column into a proper datetime format.

# %%
#df["registration_date"] = pd.to_datetime(df["registration_date"])

# %%
df['registration_date'] = pd.to_datetime(df['registration_date'], errors='coerce')
print(df.dtypes)  # Check the updated data types
# Out:
# taxpayer_id                    object
# taxpayer_name                  object
# region                         object
# sector                         object
# taxpayer_type                  object
# tax_paid                        int64
# VAT_paid                        int64
# income_tax_paid                 int64
# corporate_tax_paid              int64
# registration_date      datetime64[ns]
# compliance_status              object
# taxpayer_pin                   object
# taxpayer_id_numeric            object
# dtype: object

# %% [markdown]
# # Exercise 10

# %% [markdown]
# Merge this dataset with another dataset containing taxpayer compliance status

# %%
#df_tax_compliance = df[["taxpayer_id", "compliance_status"]].sample(frac=1).reset_index(drop=True) 
#df_tax_compliance

# %%
import pandas as pd
# Load both datasets
df_main = pd.read_excel("KRA_Class_Dataset.xlsx", sheet_name="Sheet1")
df_compliance = pd.read_excel("KRA_Taxpayer_Compliance.xlsx", sheet_name="Sheet1")

df_merged = pd.merge(df_main, df_compliance, on='taxpayer_id', how='left')

print(df_merged.head())
df_merged.head()
# Out:
#   taxpayer_id  taxpayer_name    region         sector taxpayer_type  tax_paid  \
# 0  KE75682867  Brandon Smith   Nairobi         Retail    Individual     81153
# 1  KE66755036   Megan Patton    Nakuru         Retail    Individual    240128
# 2  KE66882282  James Douglas  Machakos         Health    Individual     80388
# 3  KE31081788    Haley Moore    Nakuru  Manufacturing     Corporate     36401
# 4  KE23315092      Dean Kemp     Thika    Agriculture    Individual    207903
#
#    VAT_paid  income_tax_paid  corporate_tax_paid registration_date  \
# 0     52578            54428              108036        2022-06-16
# 1     80025            35870              116525        2024-02-02
# 2     33658           105547               85679        2017-07-12
# 3      7852            51067              125829        2023-07-06
# 4     95986           191657              128216        2015-04-14
#
#   compliance_status_x compliance_status_y
# 0           Compliant           Compliant
# ...

# %% [markdown]
# # Exercise 11

# %% [markdown]
# Write a code that counts the unique values per categorical column

# %%
import pandas as pd

# Load dataset
df = pd.read_excel("KRA_Class_Dataset.xlsx", sheet_name="Sheet1")

# Identify categorical columns (excluding numerical ones)
categorical_columns = df.select_dtypes(include=['object']).columns

# Count unique values per categorical column
unique_counts = df[categorical_columns].nunique()

# Display results
print(unique_counts)
# Out:
# taxpayer_id          1000
# taxpayer_name         992
# region                 10
# sector                 10
# taxpayer_type           3
# compliance_status       2
# dtype: int64

# %%
import pandas as pd

# Load dataset
df = pd.read_excel("KRA_Class_Dataset.xlsx", sheet_name="Sheet1")

# Define categorical columns
categorical_columns = ["region", "sector", "taxpayer_type", "compliance_status"]

# Dictionary to store counts
unique_counts = {}

# Iterate over categorical columns
for col in categorical_columns:
    unique_counts[col] = df[col].value_counts().to_dict()  # Count occurrences and convert to dictionary

# Convert to DataFrame for better readability
df_unique_counts = pd.DataFrame.from_dict(unique_counts, orient='index').transpose()

# Display results
print(df_unique_counts)

# Save breakdown to an Excel file
df_unique_counts.to_excel("Categorical_Value_Counts.xlsx", index=False)
# Out:
#                region  sector  taxpayer_type  compliance_status
# Mombasa         110.0     NaN            NaN                NaN
# Nairobi         105.0     NaN            NaN                NaN
# Meru            103.0     NaN            NaN                NaN
# Kakamega        101.0     NaN            NaN                NaN
# Nyeri           100.0     NaN            NaN                NaN
# Eldoret         100.0     NaN            NaN                NaN
# Thika           100.0     NaN            NaN                NaN
# Machakos         97.0     NaN            NaN                NaN
# Nakuru           93.0     NaN            NaN                NaN
# Kisumu           91.0     NaN            NaN                NaN
# Education         NaN   123.0            NaN                NaN
# Manufacturing     NaN   110.0            NaN                NaN
# Hospitality       NaN   106.0            NaN                NaN
# Retail            NaN   102.0            NaN                NaN
# ...

# %% [markdown]
# # Exercise 12

# %% [markdown]
# Compute the correlation matrix of continuous variables

# %%
import pandas as pd

df = pd.read_excel("KRA_Class_Dataset.xlsx", sheet_name="Sheet1")

# Compute correlation matrix for continuous variables
correlation_matrix = df[continuous_columns].corr()

# Display results
print("Correlation Matrix for Continuous Variables:\n", correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-bf439568c174> in <module>
#       4
#       5 # Compute correlation matrix for continuous variables
# ----> 6 correlation_matrix = df[continuous_columns].corr()
#       7
#       8 # Display results
#
# NameError: name 'continuous_columns' is not defined

# %%
import pandas as pd
import numpy as np

def  clean_and_preprocess_data(df):
    # """Cleans and preprocesses the dataset by handling duplicates, missing values, 
    #  inconsistent data, negative values, and encoding categorical variables."""
    
    # 1. Remove duplicate IDs, keeping the first occurrence
    #df = pd.DataFrame(data)
    df_cleaned = df.drop_duplicates(subset=['ID'], keep='first')

    # 2. Handle missing values  
    df_cleaned['Age'].fillna(df['Age'].median(), inplace=True)
    df_cleaned['Salary'].fillna(df['Salary'].mean(), inplace=True)
    df_cleaned['Department'].fillna(df['Department'].mode()[0], inplace=True)

    # 3. Normalize country names (e.g., USA, usa → USA)
    #country_mapping = {'usa': 'USA', 'United States': 'USA', 'canada': 'Canada', 'MEXICO': 'Mexico'}
    #df_cleaned['Country'] = df_cleaned['Country'].replace(country_mapping)
    
    df_cleaned['Country'] = df_cleaned['Country'].str.lower().replace
    (
        {'usa': 'united states', 'canada': 'canada', 'mexico': 'mexico'}
    )

    # 4. Fix invalid dates in 'Join_Date'
    # Convert, replacing invalid dates with NaT
    df_cleaned['Join_Date'] = pd.to_datetime(df_cleaned['Join_Date'], errors='coerce')
    
    # 5. Trim extra spaces in 'Name'
    df_cleaned['Name'] = df_cleaned['Name'].str.strip()
    
    # 6. Fix negative values in 'Experience_Years'
    #df_cleaned.loc[df_cleaned['Experience_Years'] < 0, 'Experience_Years'] = df_cleaned['Experience_Years'].median()
    # by taking absolute values
    #df_cleaned['Experience_Years'] = df_cleaned['Experience_Years'].apply(lambda x: abs(x) if x < 0 else x)
    #Replace negatives with zero
    #df_cleaned['Experience_Years'] = df_cleaned['Experience_Years'].apply(lambda x: 0 if x < 0 else x)
    #Replace negatives with median
    df['Experience_Years'] = df['Experience_Years'].apply(lambda x: df['Experience_Years'].median() if x < 0 else x)

    
    # 7. Normalize 'Salary' using Min-Max Scaling
    df_cleaned['Salary'] = (df_cleaned['Salary'] - df_cleaned['Salary'].min()) / (df_cleaned['Salary'].max() - df_cleaned['Salary'].min())
    #scaler = MinMaxScaler()
    #df['Salary'] = scaler.fit_transform(df[['Salary']])

    # 8. One-hot encode 'Department'
    df = pd.get_dummies(df, columns=['Department'], prefix='Dept')

    return df

# Example usage:
df_cleaned = clean_and_preprocess_data(df)

# Display cleaned DataFrame
print(df_cleaned)
